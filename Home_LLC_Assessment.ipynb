# %% [markdown]
# # Home L.L.C Assessment

# %%
import pandas as pd

# %% [markdown]
# 1. Loading the dataset using pandas!

# %%
df = pd .read_csv("CSUSHPISA.csv")

# %%
df.head()
# Out:
#          DATE  CSUSHPISA
# 0  1987-01-01     63.965
# 1  1987-02-01     64.424
# 2  1987-03-01     64.736
# 3  1987-04-01     65.132
# 4  1987-05-01     65.563
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['CSUSHPISA'].plot(kind='hist', bins=20, title='CSUSHPISA')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('DATE').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...

# %%
df.tail(10)
# Out:
#            DATE  CSUSHPISA
# 430  2022-11-01    298.312
# 431  2022-12-01    297.471
# 432  2023-01-01    297.025
# 433  2023-02-01    297.464
# 434  2023-03-01    298.539
# 435  2023-04-01    300.198
# 436  2023-05-01    302.620
# 437  2023-06-01    304.651
# 438  2023-07-01    306.634
# 439  2023-08-01    309.404
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_6['CSUSHPISA'].plot(kind='hist', bins=20, title='CSUSHPISA')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
# ...

# %%
df.shape
# Out:
# (440, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   DATE       440 non-null    object
#  1   CSUSHPISA  440 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 7.0+ KB

# %% [markdown]
# 2. Data Preprocessing.

# %%
df['DATE'] = pd.to_datetime(df['DATE'], format='%Y-%m-%d')
df.head()
# Out:
#         DATE  CSUSHPISA
# 0 1987-01-01     63.965
# 1 1987-02-01     64.424
# 2 1987-03-01     64.736
# 3 1987-04-01     65.132
# 4 1987-05-01     65.563
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_10['CSUSHPISA'].plot(kind='hist', bins=20, title='CSUSHPISA')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['DATE']
#                 .value_counts()
#               .reset_index(name='counts')
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   DATE       440 non-null    datetime64[ns]
#  1   CSUSHPISA  440 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 7.0 KB

# %% [markdown]
# 3. Data Visualization

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12, 6))  # Adjust the figure size as needed
plt.plot(df['DATE'], df['CSUSHPISA'], label='CSUHP values', color='blue')

#custom_xticks = ['2023-01-01', '2023-02-01', '2023-03-01']
#custom_xlabels = ['Jan 2023', 'Feb 2023', 'Mar 2023']
#plt.xticks(custom_xticks, custom_xlabels)

plt.xlabel('Dates')
plt.ylabel('CSUHP values')
plt.title('Time Series Plot of CSUHP values')
plt.grid(True)
plt.legend()
plt.tight_layout()

# %%
plt.plot(df.CSUSHPISA)

# %%
df.set_index('DATE', inplace = True)

# %%
plt.plot(df.CSUSHPISA)

# %% [markdown]
# 4. Checking the stationarity of the series.

# %%
from statsmodels.tsa.stattools import adfuller

# Load your time series data into a DataFrame, assuming 'df' is your DataFrame
#time_series = df['CSUSHPISA']

# Perform the ADF test
result = adfuller(df['CSUSHPISA'].dropna())

# Extract the test statistic and p-value
test_statistic, p_value, _, _, _, _ = result

# Check the p-value to determine stationarity
if p_value < 0.05:
    print("The time series is likely stationary.")
else:
    print("The time series is likely non-stationary.")
# Out:
# The time series is likely non-stationary.

# %%
df_diff = df['CSUSHPISA'] - df['CSUSHPISA'].shift(1)

# %%
plt.plot(df_diff)

# %%
from statsmodels.tsa.stattools import adfuller

# Load your time series data into a DataFrame, assuming 'df' is your DataFrame
#time_series = df['CSUSHPISA']

# Perform the ADF test
result = adfuller(df_diff.dropna())

# Extract the test statistic and p-value
test_statistic, p_value, _, _, _, _ = result

# Check the p-value to determine stationarity
if p_value < 0.05:
    print("The time series is likely stationary.")
else:
    print("The time series is likely non-stationary.")
# Out:
# The time series is likely non-stationary.

# %%
df_diff2 = df_diff - df_diff.shift(1)

# %%
plt.plot(df_diff2)

# %%
from statsmodels.tsa.stattools import adfuller

# Load your time series data into a DataFrame, assuming 'df' is your DataFrame
#time_series = df['CSUSHPISA']

# Perform the ADF test
result = adfuller(df_diff2.dropna())

# Extract the test statistic and p-value
test_statistic, p_value, _, _, _, _ = result

# Check the p-value to determine stationarity
if p_value < 0.05:
    print("The time series is likely stationary.")
else:
    print("The time series is likely non-stationary.")
# Out:
# The time series is likely stationary.

# %%
df_diff2
# Out:
# DATE
# 1987-01-01      NaN
# 1987-02-01      NaN
# 1987-03-01   -0.147
# 1987-04-01    0.084
# 1987-05-01    0.035
#               ...
# 2023-04-01    0.584
# 2023-05-01    0.763
# 2023-06-01   -0.391
# 2023-07-01   -0.048
# 2023-08-01    0.787
# Name: CSUSHPISA, Length: 440, dtype: float64

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

decomposition = seasonal_decompose(df_diff2.dropna(), period=54)
decomposition.plot();

# %%
from statsmodels.tsa.stattools import acf
from statsmodels.graphics.tsaplots import plot_acf

# %%
acf_plot = acf(df_diff2.dropna())

# %%
plot_acf(acf_plot);

# %%
from statsmodels.tsa.stattools import pacf
from statsmodels.graphics.tsaplots import plot_pacf

# %%
pacf_plot=pacf(df_diff2.dropna())

# %%
plot_pacf(pacf_plot,lags=10,method='ywm');

# %% [markdown]
# 5. Splitting the data.

# %%
# Split the data into training and test sets
train_set = df_diff2[:int(0.8 * len(df_diff2))]
test_set = df_diff2[int(0.8 * len(df_diff2)):]

# Print the training and test sets
print(len(train_set))
print(len(test_set))
# Out:
# 352
# 88

# %%
#pip install pmdarima

# %% [markdown]
# 6. Using first model- ARIMA!

# %%
from pmdarima import auto_arima
model = auto_arima(train_set.dropna())
auto_arima_forecasts = model.predict(start=len(train_set), end=len(df_diff2) - 1)
print(auto_arima_forecasts)
# Out:
# 2016-05-01    0.062443
# 2016-06-01   -0.062154
# 2016-07-01    0.061866
# 2016-08-01   -0.061580
# 2016-09-01    0.061295
# 2016-10-01   -0.061011
# 2016-11-01    0.060729
# 2016-12-01   -0.060448
# 2017-01-01    0.060168
# 2017-02-01   -0.059890
# Freq: MS, dtype: float64

# %%
from statsmodels.tsa.arima.model import ARIMA
arima_model = ARIMA(train_set.dropna(), order=model.order)
arima_model_fit = arima_model.fit()
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
arima_forecasts = arima_model_fit.predict(start=len(train_set), end=len(df) - 1)
print(arima_forecasts)
# Out:
# 2016-07-01    0.062366
# 2016-08-01   -0.061080
# 2016-09-01    0.061794
# 2016-10-01   -0.060511
# 2016-11-01    0.061228
#                 ...
# 2023-06-01   -0.041592
# 2023-07-01    0.042396
# 2023-08-01   -0.041203
# 2023-09-01    0.042009
# 2023-10-01   -0.040818
# Freq: MS, Name: predicted_mean, Length: 88, dtype: float64

# %%
test_set
# Out:
# DATE
# 2016-05-01    0.061
# 2016-06-01   -0.008
# 2016-07-01    0.095
# 2016-08-01    0.266
# 2016-09-01   -0.043
#               ...
# 2023-04-01    0.584
# 2023-05-01    0.763
# 2023-06-01   -0.391
# 2023-07-01   -0.048
# 2023-08-01    0.787
# Name: CSUSHPISA, Length: 88, dtype: float64

# %% [markdown]
# 7. How our model worked??

# %%
print(arima_model_fit.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:              CSUSHPISA   No. Observations:                  350
# Model:                 ARIMA(1, 0, 1)   Log Likelihood                 -21.022
# Date:                Tue, 07 Nov 2023   AIC                             50.044
# Time:                        10:57:29   BIC                             65.476
# Sample:                    03-01-1987   HQIC                            56.186
#                          - 04-01-2016
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0005      0.015      0.034      0.973      -0.028       0.029
# ar.L1         -0.9954      0.012    -85.611      0.000      -1.018      -0.973
# ma.L1          0.9770      0.022     44.499      0.000       0.934       1.020
# ...

# %%
import numpy as np

# %% [markdown]
# 9. Second model - Long Short Term Memory.

# %%
import tensorflow as tf
from tensorflow import keras
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import LSTM, Dense
from keras.callbacks import EarlyStopping

# Load and preprocess your time series data
data = df['CSUSHPISA'].values
data = data.reshape(-1, 1)

# Normalize the data
scaler = MinMaxScaler()
data = scaler.fit_transform(data)

# Split the data into training and testing sets
train_size = int(len(data) * 0.8)
train_data, test_data = data[:train_size], data[train_size:]

# Create sequences of data
def create_sequences(data, seq_length):
    sequences = []
    for i in range(len(data) - seq_length):
        sequence = data[i:i + seq_length]
        sequences.append(sequence)
    return np.array(sequences)

seq_length = 10  # Define the sequence length
X_train = create_sequences(train_data, seq_length)
y_train = train_data[seq_length:]
X_test = create_sequences(test_data, seq_length)
y_test = test_data[seq_length:]

# Build the LSTM model
model = Sequential()
model.add(LSTM(110, activation='relu', input_shape=(seq_length, 1)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')

# Early stopping to prevent overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

# Train the model
model.fit(X_train, y_train, epochs=120, batch_size=32, validation_data=(X_test, y_test), callbacks=[early_stopping])

# Make forecasts
predicted_values = model.predict(X_test)

# Inverse scaling to get actual values
predicted_values = scaler.inverse_transform(predicted_values)
y_test = scaler.inverse_transform(y_test)

# Evaluate the model
rmse = np.sqrt(mean_squared_error(y_test, predicted_values))
print(f'Root Mean Squared Error: {rmse}')
# Out:
# Epoch 1/120
# 11/11 [==============================] - 4s 68ms/step - loss: 0.0661 - val_loss: 0.3530
# Epoch 2/120
# 11/11 [==============================] - 0s 22ms/step - loss: 0.0264 - val_loss: 0.1246
# Epoch 3/120
# 11/11 [==============================] - 0s 23ms/step - loss: 0.0069 - val_loss: 0.0061
# Epoch 4/120
# 11/11 [==============================] - 0s 41ms/step - loss: 0.0037 - val_loss: 0.0104
# Epoch 5/120
# 11/11 [==============================] - 0s 46ms/step - loss: 0.0011 - val_loss: 0.0085
# Epoch 6/120
# 11/11 [==============================] - 1s 48ms/step - loss: 4.9122e-04 - val_loss: 0.0302
# Epoch 7/120
# 11/11 [==============================] - 0s 19ms/step - loss: 3.9396e-04 - val_loss: 0.0131
# Epoch 8/120
# 11/11 [==============================] - 0s 22ms/step - loss: 3.1220e-04 - val_loss: 0.0071
# Epoch 9/120
# 11/11 [==============================] - 0s 22ms/step - loss: 2.9287e-04 - val_loss: 0.0077
# Epoch 10/120
# ...

# %% [markdown]
# 10. Actual vs Predicted....

# %%
# Plot the predicted and actual values
plt.figure(figsize=(12, 6))
plt.plot(y_test, label='Actual', color='blue')
plt.plot(predicted_values, label='Predicted', color='red')
plt.xlabel('Time Steps')
plt.ylabel('Your Y-axis Label')
plt.title('LSTM Model Predictions')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
